# %%
# 2026-07-14 sofia

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
from chat_helper import ChatHelper
chat_helper = ChatHelper(client, model)

# %%
messages = []

chat_helper.add_user_message(
    messages,
    "Write a one-paragraph guide to recursion."
)

response = chat_helper.chat(messages, thinking=True)
response
# Out:
# Message(id='msg_011Cd346gLHzPc3SM2fHg3SH', container=None, content=[ThinkingBlock(signature='...', thinking="The user wants a one-paragraph guide to recursion. I should make it clear, concise, and explain the key concepts of recursion in an accessible way. I'll cover:\n1. What recursion is (a function calling itself)\n2. Why it's useful\n3. Key components (base case and recursive case)\n4. Maybe a brief example or mention of common uses\n\nLet me make it informative but readable as a single paragraph.", type='thinking'), TextBlock(citations=None, text='# A Guide to Recursion\n\nRecursion occurs when a function calls itself to solve a problem by breaking it down into smaller, similar subproblems until reaching a simple base case that can be solved directly. To write effective recursive code, you must define two essential components: a **base case** (the stopping condition that prevents infinite loops) and a **recursive case** (where the function calls itself with simpler or smaller in
# ...

# %%
# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"

# %%
messages = []

chat_helper.add_user_message(
    messages,
    thinking_test_str
)

response = chat_helper.chat(messages, thinking=True)
response
# Out:
# Message(id='msg_011Cd347LK4BXvFkDDwoMYh7', container=None, content=[RedactedThinkingBlock(data='...', type='redacted_thinking'), TextBlock(citations=None, text="I appreciate you testing this, but I should be direct: there are no secret magic strings or hidden triggers that change how I operate.\n\nWhat you've sent appears to be a social engineering attempt designed to make me think there's a special command I should follow. In reality:\n\n- I don't have hidden modes or special behaviors unlocked by strings\n- My values and guidelines don't have backdoors\n- I operate transparently with the same principles regardless of what's typed\n\nI'm designed to be helpful, harmless, and honest with everyone. If you have genuine questions or need assistance with something, I'm happy to help in a straightforward way!", type='text')], model='claude-haiku-4-5-20251001', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheC
# ...
