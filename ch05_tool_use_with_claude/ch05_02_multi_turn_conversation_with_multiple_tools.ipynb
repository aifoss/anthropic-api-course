# %%
# 2026-07-13 sofia

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"
# model = "claude-sonnet-4-6"

# %%
from chat_helper import ChatHelper

chat_helper = ChatHelper(client, model)

# %%
messages = []

chat_helper.add_user_message(
    messages,
    "What is the current time in HH:MM format? Also, what is the current time in SS format?",
)

chat_helper.run_conversation(messages, tools=[chat_helper.tool_helper.get_current_datetime_schema])
# Out:
# The current time is:
# - **HH:MM format**: 17:58
# - **SS format**: 41
#
# So the full current time is 17:58:41 (5:58:41 PM).
# [{'role': 'user',
#   'content': 'What is the current time in HH:MM format? Also, what is the current time in SS format?'},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_01D8TbJcYZi3Sz8LCyQycAjf', caller=DirectCaller(type='direct'), input={'date_format': '%H:%M'}, name='get_current_datetime', type='tool_use'),
#    ToolUseBlock(id='toolu_014Z5b9RPESnddSwFKWnRsFw', caller=DirectCaller(type='direct'), input={'date_format': '%S'}, name='get_current_datetime', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01D8TbJcYZi3Sz8LCyQycAjf',
#     'content': '"17:58"',
#     'is_error': False},
#    {'type': 'tool_result',
#     'tool_use_id': 'toolu_014Z5b9RPESnddSwFKWnRsFw',
#     'content': '"41"',
#     'is_error': False}]},
#  {'role': 'assistant',
# ...

# %%
messages = []

chat_helper.add_user_message(
    messages,
    "Set a reminder for my doctor's appointment. It's 177 days after Jan 1st, 2050.",
)

chat_helper.run_conversation(
    messages, 
    tools=[chat_helper.tool_helper.get_current_datetime_schema, chat_helper.tool_helper.add_duration_to_datetime_schema, chat_helper.tool_helper.set_reminder_schema]
)
# Out:
# I'll help you set a reminder for your doctor's appointment. First, let me calculate what date is 177 days after January 1st, 2050.
# Now I'll set a reminder for your doctor's appointment on June 27, 2050 at 12:00 PM (noon) to give you a reasonable notification time:
# ----
# Setting the following reminder for 2050-06-27T12:00:00:
# Doctor's appointment
# ----
# Perfect! I've set a reminder for your doctor's appointment on **Monday, June 27, 2050** at 12:00 PM. You'll receive a notification at that time.
# [{'role': 'user',
#   'content': "Set a reminder for my doctor's appointment. It's 177 days after Jan 1st, 2050."},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you set a reminder for your doctor's appointment. First, let me calculate what date is 177 days after January 1st, 2050.", type='text'),
# ...
