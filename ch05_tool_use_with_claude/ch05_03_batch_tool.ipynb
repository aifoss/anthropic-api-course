# %%
# 2026-07-13 sofia

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
from chat_helper import ChatHelper

chat_helper = ChatHelper(client, model)

# %%
messages = []

chat_helper.add_user_message(
    messages,
    """
    Set 2 reminders for Jan 1, 2050 at 8 AM:
        * I have a doctor's appointment
        * Taxes are due
    """    
)

chat_helper.run_conversation(messages)
# Out:
# Let me try setting these reminders individually:
# ----
# Setting the following reminder for 2050-01-01T08:00:00:
# I have a doctor's appointment
# ----
# ----
# Setting the following reminder for 2050-01-01T08:00:00:
# Taxes are due
# ----
# Perfect! I've successfully set up both reminders for January 1, 2050 at 8:00 AM:
# 1. ✓ "I have a doctor's appointment"
# 2. ✓ "Taxes are due"
#
# Both reminders are now scheduled and you'll receive notifications at that time.
# [{'role': 'user',
#   'content': "\n    Set 2 reminders for Jan 1, 2050 at 8 AM:\n        * I have a doctor's appointment\n        * Taxes are due\n    "},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_01HofuYuMvsJq1yAJecT4j28', caller=DirectCaller(type='direct'), input={'invocations': [{'name': 'set_reminder', 'arguments': '{"content": "I have a doctor\'s appointment", "timestamp": "2050-01-01T08:00:00"}'}, {'name': 'set_reminder', 'arguments': '{"content": "Taxes are due", "timestamp": "2050-01-01T08:00:00"}'}]}, name='batch_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01HofuYuMvsJq1yAJecT4j28',
#     'content': "Error: 'str' object has no attribute 'read'",
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Let me try setting these reminders individually:', type='text'),
#    ToolUseBlock(id='toolu_01QbAYsGC8KZxjEZYsRUUgD7', caller=DirectCaller(type='direct'), input={'content': "I have a doctor's appointment", 'timestamp': '2050-01-01T08:00:00'}, name='set_reminder', type='tool_use'),
#    ToolUseBlock(id='toolu_01FhSRoCeVPoWNtkFdU9hQNq', caller=DirectCaller(type='direct'), input={'content': 'Taxes are due', 'timestamp': '2050-01-01T08:00:00'}, name='set_reminder', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01QbAYsGC8KZxjEZYsRUUgD7',
#     'content': 'null',
#     'is_error': False},
#    {'type': 'tool_result',
#     'tool_use_id': 'toolu_01FhSRoCeVPoWNtkFdU9hQNq',
#     'content': 'null',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Perfect! I\'ve successfully set up both reminders for January 1, 2050 at 8:00 AM:\n1. ✓ "I have a doctor\'s appointment"\n2. ✓ "Taxes are due"\n\nBoth reminders are now scheduled and you\'ll receive notifications at that time.', type='text')]}]
