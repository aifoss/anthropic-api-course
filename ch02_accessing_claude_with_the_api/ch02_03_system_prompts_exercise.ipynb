# %%
# 2026-07-12 sofia

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
from chat_helper import ChatHelper

helper = ChatHelper(client, model)

# %%
messages = []

system = "You are a Python engineer who writes very concise code."

user_input = "Write a Python function that checks a string for duplicate characters."
print(">", user_input)

helper.add_user_message(messages, user_input)

answer = helper.chat(messages, system)

print("---")
print(answer)
print("---")
# Out:
# > Write a Python function that checks a string for duplicate characters.
# ---
# Here's a concise Python function that checks for duplicate characters in a string:
#
# ```python
# def has_duplicates(s):
#     return len(s) != len(set(s))
# ```
#
# **Usage:**
# ```python
# print(has_duplicates("hello"))   # True  ('l' appears twice)
# print(has_duplicates("world"))   # False (all unique)
# print(has_duplicates("python"))  # False (all unique)
# print(has_duplicates("mississippi"))  # True
# ```
#
# If you also want to **identify which characters are duplicates**:
#
# ```python
# def find_duplicates(s):
#     seen = set()
#     return {c for c in s if c in seen or seen.add(c)}
# ```
#
# **Usage:**
# ```python
# print(find_duplicates("hello"))       # {'l'}
# print(find_duplicates("mississippi")) # {'s', 'i', 'p'}
# print(find_duplicates("python"))      # set() (empty = no duplicates)
# ```
#
# ### How they work:
# ...
