# %%
# 2026-07-12 sofia

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
from eval_helper import EvalHelper

eval_helper = EvalHelper(client, model)

# %%
dataset = eval_helper.generate_dataset()

# %%
eval_helper.save_dataset(dataset)

# %%
import json

with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = eval_helper.run_eval(dataset)

print(json.dumps(results, indent=2))
# Out:
# Average Score: 6.166666666666667
# [
#   {
#     "test_case": {
#       "task": "Create a JSON configuration file for an AWS Lambda function that processes S3 events with 256MB memory, 30-second timeout, and VPC configuration",
#       "format": "json"
#     },
#     "output": "\nimport json\n\nlambda_config = {\n    \"FunctionName\": \"s3-event-processor\",\n    \"Runtime\": \"python3.11\",\n    \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-execution-role\",\n    \"Handler\": \"index.lambda_handler\",\n    \"Memory\": 256,\n    \"Timeout\": 30,\n    \"VpcConfig\": {\n        \"SubnetIds\": [\n            \"subnet-12345678\",\n            \"subnet-87654321\"\n        ],\n        \"SecurityGroupIds\": [\n            \"sg-12345678\"\n        ]\n    },\n    \"Environment\": {\n        \"Variables\": {\n            \"ENVIRONMENT\": \"production\"\n        }\n    },\n    \"Events\": {\n        \"S3Event\": {\n            \"Type\": \"S3\",\n            \"Properties\": {\n                \"Bucket\": \"my-bucket\",\n                \"Events\": [\n                    \"s3:ObjectCreated:*\",\n                    \"s3:ObjectRemoved:*\"\n                ]\n            }\n        }\n    },\n    \"Description\": \"Lambda function to process S3 events\",\n    \"EphemeralStorage\": {\n        \"Size\": 512\n    }\n}\n\nwith open('lambda_config.json', 'w') as f:\n    json.dump(lambda_config, f, indent=2)\n\nprint(json.dumps(lambda_config, indent=2))\n",
#     "score": 3.0,
#     "reasoning": "The solution demonstrates good understanding of Lambda core requirements but conflates different AWS configuration approaches. The memory, timeout, and VPC settings are correct, but the Events section is architecturally incorrect for the AWS Lambda API. The code would fail if executed as-is due to the Events property not being supported by the Lambda CreateFunction API. While suitable as a CloudFormation template, it doesn't match the stated requirement of a 'JSON configuration file for an AWS Lambda function.'"
#   },
#   {
#     "test_case": {
#       "task": "Write a Python function that validates AWS IAM policy ARNs using regex pattern matching",
#       "format": "python"
#     },
#     "output": "\nimport re\n\ndef validate_iam_policy_arn(arn):\n    \"\"\"\n    Validates AWS IAM policy ARNs using regex pattern matching.\n    \n    AWS IAM Policy ARN format: arn:aws:iam::<account-id>:policy/<policy-name>\n    or arn:aws:iam::<account-id>:role/<role-name>\n    or arn:aws:iam::<account-id>:user/<user-name>\n    or arn:aws:iam::aws:policy/<policy-name> (AWS managed policies)\n    \"\"\"\n    pattern = r'^arn:aws:iam::(aws|\\d{12}):(?:policy|role|user|group|instance-profile)/[a-zA-Z0-9_+=,.@\\-/]+$'\n    \n    return bool(re.match(pattern, arn))\n\n\ndef validate_iam_policy_arns(arns):\n    \"\"\"\n    Validates a list of AWS IAM policy ARNs.\n    \"\"\"\n    return [validate_iam_policy_arn(arn) for arn in arns]\n\n\nif __name__ == \"__main__\":\n    test_arns = [\n        \"arn:aws:iam::123456789012:policy/MyPolicy\",\n        \"arn:aws:iam::123456789012:role/MyRole\",\n        \"arn:aws:iam::123456789012:user/MyUser\",\n        \"arn:aws:iam::aws:policy/AdministratorAccess\",\n        \"arn:aws:iam::123456789012:group/MyGroup\",\n        \"arn:aws:iam::123456789012:instance-profile/MyInstanceProfile\",\n        \"arn:aws:iam::12345678901:policy/Invalid\",\n        \"arn:aws:iam:::policy/NoAccount\",\n        \"invalid-arn-format\",\n        \"arn:aws:iam::123456789012:policy/path/to/MyPolicy\",\n    ]\n    \n    for arn in test_arns:\n        result = validate_iam_policy_arn(arn)\n        print(f\"{arn}: {result}\")\n",
#     "score": 8.0,
#     "reasoning": "The solution demonstrates solid understanding of AWS ARN structure and regex basics, but the regex pattern has a critical flaw: it permits forward slashes in resource names which violates AWS IAM naming rules. The test case 'arn:aws:iam::123456789012:policy/path/to/MyPolicy' should fail but would pass. The character class should exclude forward slashes: `[a-zA-Z0-9_+=,.@\\-]+` instead. Additionally, lack of input validation and overly permissive character matching reduces robustness for production use."
#   },
#   {
#     "test_case": {
#       "task": "Create a regex pattern that matches valid AWS S3 bucket names (3-63 characters, lowercase letters, numbers, hyphens, no consecutive hyphens)",
#       "format": "regex"
#     },
#     "output": "\n^[a-z0-9]([a-z0-9-]{1,61}[a-z0-9])?$\n",
#     "score": 7.5,
#     "reasoning": "The regex partially addresses the requirements but has critical flaws. While it correctly prevents hyphens at boundaries and limits length, it fails to reject consecutive hyphens which is an explicit requirement. The optional middle group also creates ambiguity for very short names - the pattern accepts single characters like 'a' when minimum should be 3. A corrected pattern would need a negative lookahead like (?!.*--) to prevent consecutive hyphens."
#   }
# ]
