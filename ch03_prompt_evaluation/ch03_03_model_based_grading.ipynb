# %%
# 2026-07-12 sofia

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
from eval_helper import EvalHelper

eval_helper = EvalHelper(client, model)

# %%
import json

with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = eval_helper.run_eval(dataset)

print(json.dumps(results, indent=2))
# Out:
# Average Score: 7.333333333333333
# [
#   {
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket URI (e.g., 's3://my-bucket/path/to/file.txt') and returns a dictionary with 'bucket' and 'key' as separate fields."
#     },
#     "output": "# AWS S3 URI Parser\n\n```python\ndef parse_s3_uri(uri):\n    \"\"\"\n    Parse an AWS S3 bucket URI and return bucket and key components.\n    \n    Args:\n        uri (str): An S3 URI in the format 's3://bucket-name/path/to/file'\n        \n    Returns:\n        dict: A dictionary with 'bucket' and 'key' fields\n        \n    Raises:\n        ValueError: If the URI is invalid or doesn't follow S3 format\n        \n    Examples:\n        >>> parse_s3_uri('s3://my-bucket/path/to/file.txt')\n        {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n        \n        >>> parse_s3_uri('s3://my-bucket/')\n        {'bucket': 'my-bucket', 'key': ''}\n    \"\"\"\n    # Validate input\n    if not isinstance(uri, str):\n        raise ValueError(\"URI must be a string\")\n    \n    # Check for s3:// prefix\n    if not uri.startswith('s3://'):\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    # Remove the s3:// prefix\n    uri_without_prefix = uri[5:]\n    \n    # Handle empty URI after prefix\n    if not uri_without_prefix:\n        raise ValueError(\"URI must contain a bucket name\")\n    \n    # Split on first slash to separate bucket from key\n    parts = uri_without_prefix.split('/', 1)\n    bucket = parts[0]\n    key = parts[1] if len(parts) > 1 else ''\n    \n    # Validate bucket name (basic validation)\n    if not bucket:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return {\n        'bucket': bucket,\n        'key': key\n    }\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Test case 1: Standard S3 URI with file path\n    result1 = parse_s3_uri('s3://my-bucket/path/to/file.txt')\n    assert result1 == {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n    print(\"\u2713 Test 1 passed:\", result1)\n    \n    # Test case 2: S3 URI with just bucket\n    result2 = parse_s3_uri('s3://my-bucket/')\n    assert result2 == {'bucket': 'my-bucket', 'key': ''}\n    print(\"\u2713 Test 2 passed:\", result2)\n    \n    # Test case 3: S3 URI with bucket and trailing slash\n    result3 = parse_s3_uri('s3://my-bucket')\n    assert result3 == {'bucket': 'my-bucket', 'key': ''}\n    print(\"\u2713 Test 3 passed:\", result3)\n    \n    # Test case 4: S3 URI with nested paths\n    result4 = parse_s3_uri('s3://data-bucket/2024/01/15/report.csv')\n    assert result4 == {'bucket': 'data-bucket', 'key': '2024/01/15/report.csv'}\n    print(\"\u2713 Test 4 passed:\", result4)\n    \n    # Test case 5: S3 URI with special characters in key\n    result5 = parse_s3_uri('s3://my-bucket/documents/my-file_v2.1.pdf')\n    assert result5 == {'bucket': 'my-bucket', 'key': 'documents/my-file_v2.1.pdf'}\n    print(\"\u2713 Test 5 passed:\", result5)\n    \n    # Test error cases\n    print(\"\\nTesting error cases:\")\n    \n    try:\n        parse_s3_uri('https://my-bucket/file.txt')\n        print(\"\u2717 Should have raised ValueError for invalid scheme\")\n    except ValueError as e:\n        print(f\"\u2713 Correctly raised error: {e}\")\n    \n    try:\n        parse_s3_",
#     "score": 7,
#     "reasoning": "The solution successfully implements the core requirement of parsing S3 URIs and returning bucket/key components. The code is well-structured with proper input validation and error handling. However, the solution is incomplete due to a truncated test file, and it lacks AWS S3-compliant bucket name validation. While adequate for basic use cases, it would benefit from stricter validation to prevent invalid bucket names from being accepted. The incomplete test suite is a significant issue that prevents full confidence in the implementation."
#   },
#   {
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to all objects in an S3 bucket named 'my-data-bucket'."
#     },
#     "output": "# AWS IAM S3 Read-Only Policy\n\nHere's a JSON object that represents an IAM policy for read-only access to all objects in an S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3ReadOnlyAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Sid\": \"S3ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Policy Breakdown:\n\n**Statement 1 - S3ReadOnlyAccess:**\n- **Effect**: Allow - grants permission\n- **Actions**:\n  - `s3:GetObject` - read objects from the bucket\n  - `s3:GetObjectVersion` - read object versions (if versioning is enabled)\n- **Resource**: `arn:aws:s3:::my-data-bucket/*` - applies to all objects in the bucket\n\n**Statement 2 - S3ListBucket:**\n- **Effect**: Allow - grants permission\n- **Actions**:\n  - `s3:ListBucket` - list bucket contents\n  - `s3:GetBucketVersioning` - check versioning status\n- **Resource**: `arn:aws:s3:::my-data-bucket` - applies to the bucket itself\n\nThis policy provides the minimum permissions needed for read-only access to the bucket and its objects.",
#     "score": 7,
#     "reasoning": "The policy successfully provides read-only access to S3 bucket objects with correct IAM syntax and proper resource scoping. However, it includes two unnecessary permissions (GetObjectVersion and GetBucketVersioning) that exceed a minimal read-only policy. For a truly minimal read-only access policy, only s3:GetObject and s3:ListBucket are essential. The solution is functionally correct but could be more tightly scoped to the principle of least privilege."
#   },
#   {
#     "test_case": {
#       "task": "Write a Regex pattern that matches valid AWS EC2 instance IDs (format: i-followed by 8 or 17 hexadecimal characters, e.g., 'i-0abcd1234efgh5678')."
#     },
#     "output": "# AWS EC2 Instance ID Regex Pattern\n\nHere's the correct regex pattern for matching valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{8}([0-9a-f]{9})?$\n```\n\n## Pattern Breakdown\n\n| Component | Meaning |\n|-----------|---------|\n| `^` | Start of string |\n| `i-` | Literal prefix (required) |\n| `[0-9a-f]{8}` | Exactly 8 hexadecimal characters (0-9, a-f) |\n| `([0-9a-f]{9})?` | Optional group of 9 additional hex characters |\n| `$` | End of string |\n\n## Why This Works\n\n- **Short format**: `i-` + 8 hex chars = 10 characters total (e.g., `i-0abcd1234`)\n- **Long format**: `i-` + 8 hex chars + 9 hex chars = 19 characters total (e.g., `i-0abcd1234efgh5678`)\n\n## Implementation Examples\n\n### JavaScript\n```javascript\nconst pattern = /^i-[0-9a-f]{8}([0-9a-f]{9})?$/;\n\nconsole.log(pattern.test('i-0abcd1234'));        // true\nconsole.log(pattern.test('i-0abcd1234efgh5678')); // true\nconsole.log(pattern.test('i-0abcd123'));         // false (too short)\nconsole.log(pattern.test('i-ABCD1234'));         // false (uppercase)\n```\n\n### Python\n```python\nimport re\n\npattern = r'^i-[0-9a-f]{8}([0-9a-f]{9})?$'\n\ntest_ids = [\n    'i-0abcd1234',           # Valid (short)\n    'i-0abcd1234efgh5678',   # Valid (long)\n    'i-0abcd123',            # Invalid\n    'i-ABCD1234efgh5678',    # Invalid (uppercase)\n]\n\nfor id in test_ids:\n    print(f\"{id}: {bool(re.match(pattern, id))}\")\n```\n\n### Case-Insensitive Variant\n```regex\n^i-[0-9a-fA-F]{8}([0-9a-fA-F]{9})?$\n```\nAdd the `i` flag for case-insensitive matching if needed.",
#     "score": 8,
#     "reasoning": "The solution provides a technically correct regex pattern that properly validates AWS EC2 instance IDs (i- followed by either 8 or 17 hex characters). The explanation is comprehensive and well-organized. However, the example uses an invalid instance ID string containing 'g' and 'h' characters, which undermines confidence in the solution despite the pattern being correct. A minor but notable issue in an otherwise solid response."
#   }
# ]
