# %%
# 2026-07-12 sofia

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
from eval_helper import EvalHelper

helper = EvalHelper(client, model)

# %%
import json

with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = helper.run_eval(dataset)

print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket URI (e.g., 's3://my-bucket/path/to/file.txt') and returns a dictionary with 'bucket' and 'key' as separate fields."
#     },
#     "output": "# AWS S3 URI Parser\n\nHere's a Python function that parses AWS S3 bucket URIs:\n\n```python\ndef parse_s3_uri(uri: str) -> dict:\n    \"\"\"\n    Parse an AWS S3 bucket URI and return bucket and key as separate fields.\n    \n    Args:\n        uri (str): S3 URI in format 's3://bucket-name/path/to/file'\n        \n    Returns:\n        dict: Dictionary with 'bucket' and 'key' fields\n        \n    Raises:\n        ValueError: If the URI format is invalid\n        \n    Examples:\n        >>> parse_s3_uri('s3://my-bucket/path/to/file.txt')\n        {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n        \n        >>> parse_s3_uri('s3://my-bucket/')\n        {'bucket': 'my-bucket', 'key': ''}\n    \"\"\"\n    # Remove whitespace\n    uri = uri.strip()\n    \n    # Check if URI starts with s3://\n    if not uri.startswith('s3://'):\n        raise ValueError(f\"Invalid S3 URI: {uri}. Must start with 's3://'\")\n    \n    # Remove the 's3://' prefix\n    uri_without_scheme = uri[5:]\n    \n    # Find the first '/' to separate bucket from key\n    first_slash_index = uri_without_scheme.find('/')\n    \n    if first_slash_index == -1:\n        # No key provided, only bucket\n        bucket = uri_without_scheme\n        key = ''\n    else:\n        # Split bucket and key\n        bucket = uri_without_scheme[:first_slash_index]\n        key = uri_without_scheme[first_slash_index + 1:]\n    \n    # Validate bucket name is not empty\n    if not bucket:\n        raise ValueError(f\"Invalid S3 URI: {uri}. Bucket name cannot be empty\")\n    \n    return {\n        'bucket': bucket,\n        'key': key\n    }\n```\n\n## Usage Examples\n\n```python\n# Example 1: Standard file path\nresult = parse_s3_uri('s3://my-bucket/path/to/file.txt')\nprint(result)\n# Output: {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n\n# Example 2: Bucket only\nresult = parse_s3_uri('s3://my-bucket/')\nprint(result)\n# Output: {'bucket': 'my-bucket', 'key': ''}\n\n# Example 3: With nested directories\nresult = parse_s3_uri('s3://data-bucket/2024/01/15/report.csv')\nprint(result)\n# Output: {'bucket': 'data-bucket', 'key': '2024/01/15/report.csv'}\n\n# Example 4: File with special characters\nresult = parse_s3_uri('s3://my-bucket/documents/my-file_v2.0.pdf')\nprint(result)\n# Output: {'bucket': 'my-bucket', 'key': 'documents/my-file_v2.0.pdf'}\n```\n\n## Error Handling\n\n```python\n# Invalid URI format\ntry:\n    parse_s3_uri('https://my-bucket/file.txt')\nexcept ValueError as e:\n    print(f\"Error: {e}\")\n    # Output: Error: Invalid S3 URI: https://my-bucket/file.txt. Must start with 's3://'\n\n# Empty bucket name\ntry:\n    parse_s3_uri('s3:///path/to/file.txt')\nexcept ValueError as e:\n    print(f\"Error: {e}\")\n    # Output: Error: Invalid S3 URI: s3:///path/to/file.txt. Bucket name cannot be empty\n```\n\n## Alternative Implementation (Using urllib.parse)\n\nIf you prefer a more robust solution using Python's built-in URL parsing:\n\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_uri_v2(uri: str) -> dict:\n    \"\"\"\n    ",
#     "score": 10
#   },
#   {
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to all objects in an S3 bucket named 'my-data-bucket'."
#     },
#     "output": "# AWS IAM Read-Only S3 Policy\n\nHere's a JSON object that allows read-only access to all objects in the S3 bucket 'my-data-bucket':\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Explanation\n\nThis policy includes two statements:\n\n1. **First Statement** - Object-level permissions:\n   - `s3:GetObject` - Allows reading/downloading objects from the bucket\n   - `s3:GetObjectVersion` - Allows retrieving specific versions of objects\n   - Applied to `arn:aws:s3:::my-data-bucket/*` (all objects in the bucket)\n\n2. **Second Statement** - Bucket-level permissions:\n   - `s3:ListBucket` - Allows listing the contents of the bucket\n   - `s3:GetBucketVersioning` - Allows checking the bucket's versioning status\n   - Applied to `arn:aws:s3:::my-data-bucket` (the bucket itself)\n\nThis policy provides complete read-only access while preventing any write, delete, or modification operations.",
#     "score": 10
#   },
#   {
#     "test_case": {
#       "task": "Write a Regex pattern that matches valid AWS EC2 instance IDs (format: i-followed by 8 or 17 hexadecimal characters, e.g., 'i-0abcd1234efgh5678')."
#     },
#     "output": "# AWS EC2 Instance ID Regex Pattern\n\nHere's the regex pattern that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{8}([0-9a-f]{9})?$\n```\n\n## Explanation\n\n| Component | Purpose |\n|-----------|---------|\n| `^` | Start of string anchor |\n| `i-` | Literal prefix required for all EC2 instance IDs |\n| `[0-9a-f]{8}` | Exactly 8 hexadecimal characters (lowercase) |\n| `([0-9a-f]{9})?` | Optional group of 9 additional hex characters (makes total 17 possible) |\n| `$` | End of string anchor |\n\n## Pattern Breakdown\n\n- **8 hex characters**: `i-` + 8 chars = `i-0abcd1234` \u2713\n- **17 hex characters**: `i-` + 17 chars = `i-0abcd1234efgh5678` \u2713\n\n## Examples\n\n### Valid Matches\n```\ni-0abcd1234      (8 hex chars)\ni-0abcd1234efgh5678  (17 hex chars)\ni-1234567890abcdef   (17 hex chars)\ni-ffffffffffffffff   (17 hex chars)\n```\n\n### Invalid Matches\n```\ni-0abcd123       (only 7 hex chars)\ni-0abcd12345     (9 hex chars - not 8 or 17)\ni-0ABCD1234      (uppercase not allowed)\n0abcd1234        (missing 'i-' prefix)\n```\n\n## Implementation Examples\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{8}([0-9a-f]{9})?$/;\nconsole.log(pattern.test('i-0abcd1234'));        // true\nconsole.log(pattern.test('i-0abcd1234efgh5678')); // true\nconsole.log(pattern.test('i-123'));              // false\n```\n\n**Python:**\n```python\nimport re\npattern = r'^i-[0-9a-f]{8}([0-9a-f]{9})?$'\nprint(re.match(pattern, 'i-0abcd1234'))          # Match\nprint(re.match(pattern, 'i-0abcd1234efgh5678'))  # Match\n```",
#     "score": 10
#   }
# ]
