# %%
# 2026-07-12 sofia

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
from eval_helper import EvalHelper

eval_helper = EvalHelper(client, model)

# %%
import json

dataset = eval_helper.generate_dataset()

print(json.dumps(dataset, indent=2))
# Out:
# [
#   {
#     "task": "Parse an AWS S3 bucket name from a full S3 URI (e.g., 's3://my-bucket-name/path/to/object') and extract only the bucket name",
#     "format": "regex",
#     "solution_criteria": "Should correctly extract bucket names from S3 URIs in the format 's3://bucket-name/...' and handle bucket names with hyphens and numbers. Should not include the path after the bucket name."
#   },
#   {
#     "task": "Write a Python function that validates if a given string is a valid AWS IAM role ARN. A valid ARN should follow the pattern: arn:aws:iam::account-id:role/role-name",
#     "format": "python",
#     "solution_criteria": "Function should return True for valid IAM role ARNs and False for invalid ones. Should validate the presence of all required components (arn:aws:iam, account-id as 12 digits, role/ prefix, and role name). Should handle edge cases like extra slashes or missing components."
#   },
#   {
#     "task": "Create a JSON CloudWatch Alarm configuration for monitoring EC2 CPU utilization that triggers when average CPU exceeds 80% over a 5-minute period",
#     "format": "json",
#     "solution_criteria": "JSON should include AlarmName, MetricName (CPUUtilization), Namespace (AWS/EC2), Statistic (Average), Period (300 seconds), EvaluationPeriods, Threshold (80), ComparisonOperator (GreaterThanThreshold), and AlarmActions. Should be valid CloudWatch alarm syntax."
#   }
# ]

# %%
eval_helper.save_dataset(dataset)

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = eval_helper.run_eval(dataset)

print(json.dumps(results, indent=2))
# Out:
# Average Score: 7.0
# [
#   {
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI (e.g., 's3://my-bucket-name/path/to/object') and extract only the bucket name",
#       "format": "regex",
#       "solution_criteria": "Should correctly extract bucket names from S3 URIs in the format 's3://bucket-name/...' and handle bucket names with hyphens and numbers. Should not include the path after the bucket name."
#     },
#     "output": "\nimport re\n\ndef extract_s3_bucket_name(s3_uri):\n    match = re.match(r's3://([^/]+)', s3_uri)\n    if match:\n        return match.group(1)\n    return None\n",
#     "score": 8.5,
#     "reasoning": "The solution correctly satisfies the stated criteria by extracting bucket names from standard S3 URIs with hyphens and numbers while excluding paths. The regex pattern is appropriate and concise. However, the implementation lacks defensive programming practices such as input validation and AWS naming convention checks, which would be expected in production code. The function handles the happy path well but could fail gracefully with better error handling."
#   },
#   {
#     "test_case": {
#       "task": "Write a Python function that validates if a given string is a valid AWS IAM role ARN. A valid ARN should follow the pattern: arn:aws:iam::account-id:role/role-name",
#       "format": "python",
#       "solution_criteria": "Function should return True for valid IAM role ARNs and False for invalid ones. Should validate the presence of all required components (arn:aws:iam, account-id as 12 digits, role/ prefix, and role name). Should handle edge cases like extra slashes or missing components."
#     },
#     "output": "\nimport re\n\ndef is_valid_iam_role_arn(arn: str) -> bool:\n    pattern = r'^arn:aws:iam::\\d{12}:role/[\\w+=,.@-]+$'\n    return bool(re.match(pattern, arn))\n",
#     "score": 8.5,
#     "reasoning": "The solution correctly implements the core validation logic for the basic ARN structure and handles most standard cases. However, it lacks enforcement of AWS's specific constraints on role name composition and length. The regex pattern is permissive in what it accepts for role names, potentially validating ARNs that AWS would reject. Adding input type checking and role name length validation would make this production-ready."
#   },
#   {
#     "test_case": {
#       "task": "Create a JSON CloudWatch Alarm configuration for monitoring EC2 CPU utilization that triggers when average CPU exceeds 80% over a 5-minute period",
#       "format": "json",
#       "solution_criteria": "JSON should include AlarmName, MetricName (CPUUtilization), Namespace (AWS/EC2), Statistic (Average), Period (300 seconds), EvaluationPeriods, Threshold (80), ComparisonOperator (GreaterThanThreshold), and AlarmActions. Should be valid CloudWatch alarm syntax."
#     },
#     "output": "\nimport json\n\nalarm_config = {\n    \"AlarmName\": \"EC2-High-CPU-Utilization\",\n    \"MetricName\": \"CPUUtilization\",\n    \"Namespace\": \"AWS/EC2\",\n    \"Statistic\": \"Average\",\n    \"Period\": 300,\n    \"EvaluationPeriods\": 1,\n    \"Threshold\": 80.0,\n    \"ComparisonOperator\": \"GreaterThanThreshold\",\n    \"Dimensions\": [\n        {\n            \"Name\": \"InstanceId\",\n            \"Value\": \"i-0123456789abcdef0\"\n        }\n    ],\n    \"AlarmDescription\": \"Triggers when average CPU utilization exceeds 80% over a 5-minute period\",\n    \"AlarmActions\": [\n        \"arn:aws:sns:us-east-1:123456789012:AlertTopic\"\n    ],\n    \"TreatMissingData\": \"notBreaching\"\n}\n\nprint(json.dumps(alarm_config, indent=2))\n",
#     "score": 4.0,
#     "reasoning": "The solution fully satisfies all specified criteria with correct CloudWatch alarm configuration. The alarm will trigger when average EC2 CPU exceeds 80% over a 5-minute period as required. The JSON structure is valid and syntax-correct. However, the solution lacks flexibility due to hard-coded resource identifiers (InstanceId and SNS ARN), which limits its reusability in real environments. These are minor issues as they represent best practices rather than functional failures."
#   }
# ]
